# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import time, os

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
#For league season websites, get all "target=" locations for matches'
#Each one of these will give you a game board
#Ex: https://tv.dartconnect.com/leaguestandings/wcdo/59/all
driver = webdriver.Chrome(chromedriver)
driver.get("https://tv.dartconnect.com/leaguestandings/wcdo/59/all")

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
mplinks = soup.find_all(class_="mp_link")

# %%
teamid = []
for link in mplinks:
    teamid.append(link.get('data-id'))

# %%
teamclick = driver.find_elements_by_class_name('mp_link')

# %%
def seasonmatches(season):
    SeaMatch = []
    teamsoup = BeautifulSoup(driver.page_source, 'html.parser')
    matlinks = teamsoup.find_all('a')
    for link in matlinks:
        SeaMatch.append(link.get("target"))
    SeaMatch = SeaMatch[5:]
    return SeaMatch

# %%
import time

# %%
LeagueMatches = []

# %%
for team in teamclick:
    team.click()
    time.sleep(1)
    LeagueMatches.append(seasonmatches(team))

# %%
LeagueMatches
# Out:
# [['57577da1c3cd6f0f304014b0',
#   '5760ad734466ed176e1ff0fd',
#   '5769e7e04466ed176e2032d1',
#   '578596089d17a86022a57fd3',
#   '578ed09d459bc004705d90fd',
#   '57980ed8852cf9e15e1c9d63',
#   '57aa7eeb6aeabb504bcda52d'],
#  ['5743de557ed0f25d02dd4d2c',
#   '57566936c3cd6f0f304009db',
#   '575f5d774466ed176e1fe559',
#   '576898684466ed176e202605',
#   '5784780a9d17a86022a577e0',
#   '5796b8ff8f810c3838bba9e7'],
#  ['576898684466ed176e202605', '57aa7eeb6aeabb504bcda52d'],
#  ['575f5d774466ed176e1fe559', '5796b8ff8f810c3838bba9e7'],
#  ['57577da1c3cd6f0f304014b0', '578ed09d459bc004705d90fd'],
#  ['5743de557ed0f25d02dd4d2c', '5784780a9d17a86022a577e0'],
#  ['5760ad734466ed176e1ff0fd', '57980ed8852cf9e15e1c9d63'],
#  ['578596089d17a86022a57fd3'],
#  ['5769e7e04466ed176e2032d1'],
#  ['57566936c3cd6f0f304009db'],
#  [],
#  [],
#  [],
#  [],
#  ['5731394f0d39b85a663cde40',
#   '573a73a3336cf5957426d120',
#   '5743ad867ed0f25d02dd49e1',
#   '57561c70c3cd6f0f304004fe',
#   '575f5f314466ed176e1fe5a5',
#   '57689b4c4466ed176e202672',
#   '5771d06f4466ed176e206d77',
#   '578444bf9d17a86022a57356',
#   '578d7fd7237e3d0b44e45815',
#   '5796bd998f810c3838bbaa64',
#   '57aa7f336aeabb504bcda544',
#   '57b2669d3b07ebf141145e36',
#   '57b3bace93a0cf1e592fb274'],
#  ['573288e067d7ed1e768bff84',
#   '573bc19995b70eff039fd768',
#   '5744feee80e1f3821b7e5fe7',
#   '2275',
#   '5760ac9d4466ed176e1ff0c4',
#   '5769e6824466ed176e20329b',
#   '57731f6e4466ed176e207873',
#   '578596929d17a86022a57fed',
#   '578ed44e459bc004705d91b2',
#   '57980dc2852cf9e15e1c9d26',
#   '57aa7f336aeabb504bcda544'],
#  ['573288e067d7ed1e768bff84',
#   '5744fe0a80e1f3821b7e5fcf',
#   '5757718fc3cd6f0f304012b8',
#   '5760ae5b4466ed176e1ff12e',
#   '5769e6824466ed176e20329b',
#   '577322484466ed176e2078f3',
#   '578ed4b3459bc004705d91d4',
#   '57980dc0852cf9e15e1c9d24',
#   '57aa83766aeabb504bcda604',
#   '57b2669d3b07ebf141145e36'],
#  ['573a727b336cf5957426d104',
#   '5743ad867ed0f25d02dd49e1',
#   '57562203c3cd6f0f30400597',
#   '575f5c694466ed176e1fe52b',
#   '576895bb4466ed176e2025a8',
#   '5771d00d4466ed176e206d67',
#   '578444bf9d17a86022a57356',
#   '5796bcd38f810c3838bbaa4f',
#   '57aa83766aeabb504bcda604'],
#  ['573bc19995b70eff039fd768',
#   '5744febc80e1f3821b7e5fe3',
#   '5757718fc3cd6f0f304012b8',
#   '5760acdc4466ed176e1ff0d3',
#   '5769ea124466ed176e20333c',
#   '576a1aa84466ed176e20388d',
#   '57731f6e4466ed176e207873',
#   '578ed4b3459bc004705d91d4',
#   '57a14696a1452d295068c518'],
#  ['573a73a3336cf5957426d120',
#   '5743acff7ed0f25d02dd49d4',
#   '57562203c3cd6f0f30400597',
#   '575f5d734466ed176e1fe557',
#   '5768b7334466ed176e202978',
#   '5771d06f4466ed176e206d77',
#   '5784457c9d17a86022a57373',
#   '5796c0318f810c3838bbaab1'],
#  ['57561c70c3cd6f0f304004fe',
#   '575f5d734466ed176e1fe557',
#   '576895bb4466ed176e2025a8',
#   '578d7fd7237e3d0b44e45815',
#   '5796c0318f810c3838bbaab1'],
#  ['5731394f0d39b85a663cde40',
#   '5743acff7ed0f25d02dd49d4',
#   '575f5c694466ed176e1fe52b',
#   '57689b4c4466ed176e202672',
#   '5784457c9d17a86022a57373',
#   '5796bcd38f810c3838bbaa4f'],
#  ['5744feee80e1f3821b7e5fe7',
#   '5760acdc4466ed176e1ff0d3',
#   '577322484466ed176e2078f3',
#   '578596929d17a86022a57fed'],
#  ['5744febc80e1f3821b7e5fe3',
#   '2275',
#   '5760ae5b4466ed176e1ff12e',
#   '578ed44e459bc004705d91b2',
#   '57980dc0852cf9e15e1c9d24',
#   '57a14696a1452d295068c518'],
#  ['573a727b336cf5957426d104',
#   '575f5f314466ed176e1fe5a5',
#   '5768b7334466ed176e202978',
#   '5771d00d4466ed176e206d67',
#   '5796bd998f810c3838bbaa64'],
#  ['5744fe0a80e1f3821b7e5fcf',
#   '5760ac9d4466ed176e1ff0c4',
#   '5769ea124466ed176e20333c',
#   '576a1aa84466ed176e20388d',
#   '57980dc2852cf9e15e1c9d26'],
#  ['57b3bace93a0cf1e592fb274'],
#  ['5732895f67d7ed1e768bff98',
#   '573bc28595b70eff039fd795',
#   '574500c580e1f3821b7e602b',
#   '57577489c3cd6f0f3040133f',
#   '5760ad264466ed176e1ff0e0',
#   '2418',
#   '577327a94466ed176e2079c4',
#   '578596589d17a86022a57fdf',
#   '578ed311459bc004705d9177',
#   '57980e14852cf9e15e1c9d36',
#   '57b3bc5a93a0cf1e592fb2ab'],
#  ['5732886467d7ed1e768bff66',
#   '573bc3a395b70eff039fd7d6',
#   '574500c580e1f3821b7e602b',
#   '5757758cc3cd6f0f3040136c',
#   '5760ad7a4466ed176e1ff105',
#   '5769e9474466ed176e203310',
#   '577475384466ed176e2085fc',
#   '578596589d17a86022a57fdf',
#   '578ed220459bc004705d9143',
#   '57980cee852cf9e15e1c9cfe',
#   '57b3bc5a93a0cf1e592fb2ab'],
#  ['5732886467d7ed1e768bff66',
#   '573bc78f95b70eff039fd87e',
#   '2162',
#   '5757756ec3cd6f0f3040135e',
#   '5760ad264466ed176e1ff0e0',
#   '5769e9474466ed176e203310',
#   '5773242e4466ed176e20792e',
#   '578598829d17a86022a58039',
#   '578ed454459bc004705d91b6',
#   '57980e14852cf9e15e1c9d36'],
#  ['5732895f67d7ed1e768bff98',
#   '573bc78f95b70eff039fd87e',
#   '5757758cc3cd6f0f3040136c',
#   '5760b0a04466ed176e1ff16a',
#   '2418',
#   '5773242e4466ed176e20792e',
#   '5785a3de9d17a86022a581f2',
#   '578ed220459bc004705d9143',
#   '57980bac852cf9e15e1c9cce'],
#  ['573289eb67d7ed1e768bffbc',
#   '573bc3a395b70eff039fd7d6',
#   '2162',
#   '57577489c3cd6f0f3040133f',
#   '5760b0a04466ed176e1ff16a',
#   '5769eb6d4466ed176e203392',
#   '577475384466ed176e2085fc',
#   '578598829d17a86022a58039',
#   '578ed311459bc004705d9177',
#   '57980bac852cf9e15e1c9cce'],
#  ['573289eb67d7ed1e768bffbc',
#   '573bc28595b70eff039fd795',
#   '5757756ec3cd6f0f3040135e',
#   '5760ad7a4466ed176e1ff105',
#   '5769eb6d4466ed176e203392',
#   '577327a94466ed176e2079c4',
#   '5785a3de9d17a86022a581f2',
#   '578ed454459bc004705d91b6',
#   '57980cee852cf9e15e1c9cfe']]

# %%
# The 5-digit game codes are located at "https://members.dartconnect.com/history/report/event/"<5dgcd>
# There may be links to matches at those locations.

# %%
CleanMatch = []
for team in LeagueMatches:
    for match in team:
        if match not in CleanMatch:
            CleanMatch.append(match)
        else:
            continue
CleanMatch
# Out:
# ['57577da1c3cd6f0f304014b0',
#  '5760ad734466ed176e1ff0fd',
#  '5769e7e04466ed176e2032d1',
#  '578596089d17a86022a57fd3',
#  '578ed09d459bc004705d90fd',
#  '57980ed8852cf9e15e1c9d63',
#  '57aa7eeb6aeabb504bcda52d',
#  '5743de557ed0f25d02dd4d2c',
#  '57566936c3cd6f0f304009db',
#  '575f5d774466ed176e1fe559',
#  '576898684466ed176e202605',
#  '5784780a9d17a86022a577e0',
#  '5796b8ff8f810c3838bba9e7',
#  '5731394f0d39b85a663cde40',
#  '573a73a3336cf5957426d120',
#  '5743ad867ed0f25d02dd49e1',
#  '57561c70c3cd6f0f304004fe',
#  '575f5f314466ed176e1fe5a5',
#  '57689b4c4466ed176e202672',
#  '5771d06f4466ed176e206d77',
#  '578444bf9d17a86022a57356',
#  '578d7fd7237e3d0b44e45815',
#  '5796bd998f810c3838bbaa64',
#  '57aa7f336aeabb504bcda544',
#  '57b2669d3b07ebf141145e36',
#  '57b3bace93a0cf1e592fb274',
#  '573288e067d7ed1e768bff84',
#  '573bc19995b70eff039fd768',
#  '5744feee80e1f3821b7e5fe7',
#  '2275',
#  '5760ac9d4466ed176e1ff0c4',
#  '5769e6824466ed176e20329b',
#  '57731f6e4466ed176e207873',
#  '578596929d17a86022a57fed',
#  '578ed44e459bc004705d91b2',
#  '57980dc2852cf9e15e1c9d26',
#  '5744fe0a80e1f3821b7e5fcf',
#  '5757718fc3cd6f0f304012b8',
#  '5760ae5b4466ed176e1ff12e',
#  '577322484466ed176e2078f3',
#  '578ed4b3459bc004705d91d4',
#  '57980dc0852cf9e15e1c9d24',
#  '57aa83766aeabb504bcda604',
#  '573a727b336cf5957426d104',
#  '57562203c3cd6f0f30400597',
#  '575f5c694466ed176e1fe52b',
#  '576895bb4466ed176e2025a8',
#  '5771d00d4466ed176e206d67',
#  '5796bcd38f810c3838bbaa4f',
#  '5744febc80e1f3821b7e5fe3',
#  '5760acdc4466ed176e1ff0d3',
#  '5769ea124466ed176e20333c',
#  '576a1aa84466ed176e20388d',
#  '57a14696a1452d295068c518',
#  '5743acff7ed0f25d02dd49d4',
#  '575f5d734466ed176e1fe557',
#  '5768b7334466ed176e202978',
#  '5784457c9d17a86022a57373',
#  '5796c0318f810c3838bbaab1',
#  '5732895f67d7ed1e768bff98',
#  '573bc28595b70eff039fd795',
#  '574500c580e1f3821b7e602b',
#  '57577489c3cd6f0f3040133f',
#  '5760ad264466ed176e1ff0e0',
#  '2418',
#  '577327a94466ed176e2079c4',
#  '578596589d17a86022a57fdf',
#  '578ed311459bc004705d9177',
#  '57980e14852cf9e15e1c9d36',
#  '57b3bc5a93a0cf1e592fb2ab',
#  '5732886467d7ed1e768bff66',
#  '573bc3a395b70eff039fd7d6',
#  '5757758cc3cd6f0f3040136c',
#  '5760ad7a4466ed176e1ff105',
#  '5769e9474466ed176e203310',
#  '577475384466ed176e2085fc',
#  '578ed220459bc004705d9143',
#  '57980cee852cf9e15e1c9cfe',
#  '573bc78f95b70eff039fd87e',
#  '2162',
#  '5757756ec3cd6f0f3040135e',
#  '5773242e4466ed176e20792e',
#  '578598829d17a86022a58039',
#  '578ed454459bc004705d91b6',
#  '5760b0a04466ed176e1ff16a',
#  '5785a3de9d17a86022a581f2',
#  '57980bac852cf9e15e1c9cce',
#  '573289eb67d7ed1e768bffbc',
#  '5769eb6d4466ed176e203392']

# %%
clean = pd.DataFrame(CleanMatch)

# %%
clean
# Out:
#                            0
# 0   57577da1c3cd6f0f304014b0
# 1   5760ad734466ed176e1ff0fd
# 2   5769e7e04466ed176e2032d1
# 3   578596089d17a86022a57fd3
# 4   578ed09d459bc004705d90fd
# ..                       ...
# 84  5760b0a04466ed176e1ff16a
# 85  5785a3de9d17a86022a581f2
# 86  57980bac852cf9e15e1c9cce
# 87  573289eb67d7ed1e768bffbc
# 88  5769eb6d4466ed176e203392
#
# [89 rows x 1 columns]

# %%
#Export all match ID's to csv. Format LEAGUE-SEASON-CONTENTS.
clean.to_csv("WCD-16S-Matches.csv")
